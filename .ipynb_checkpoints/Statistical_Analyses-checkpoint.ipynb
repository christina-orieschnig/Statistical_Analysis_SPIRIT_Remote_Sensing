# %%
#####################################################################################################
### this script provides a statistical analysis of the evolution of different vegetation indices on irrigated 
### and not irrigated vineyards in the area of the canal du Gignac 
#####################################################################################################

# %%
# import necessary packages 
from io import StringIO
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import datetime
import os
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import math
from functools import reduce
import json 
import csv
import pandas as pd 
from pandas.io.json import json_normalize
import json
from datetime import datetime
#import pymannkendall as mk
#import pyhomogeneity as hg
from matplotlib.dates import date2num
from datetime import datetime
import matplotlib.ticker as ticker
import numpy as np
from scipy import stats
rng = np.random.default_rng()

# %%
# import data 

# chrips 

chirps = pd.read_csv('ChirpsPrecipitation.csv')
chirps = chirps.drop(columns = ['system:index', '.geo']) 
chirps['date'] = pd.to_datetime(chirps['date'])
chirps = chirps.set_index('date')

# not irrigated areas 

ni = pd.read_csv('not_irrigated_results.csv')
ni = ni.drop(columns=['.geo'])
ni['system:index'] = ni['system:index'].str[:8]
ni['system:index'] = pd.to_datetime(ni['system:index'])
ni = ni.set_index('system:index')

#  irrigated areas 

i = pd.read_csv('irrigated_results.csv')
i = i.drop(columns=['.geo'])
i['system:index'] = i['system:index'].str[:8]
i['system:index'] = pd.to_datetime(i['system:index'])
i = i.set_index('system:index')

# %%
### merge dataframes - add separate one with precipitation 

all_data = pd.merge(
            i,
            ni,
            how="inner",
            left_index=True,
            right_index=True,
            suffixes=("_i", "_ni"),
            copy=True
        )
all_data_withprecip = pd.merge(
            all_data,
            chirps,
            how="right",
            left_index=True,
            right_index=True
        )

all_data.head()
# Out:
#                        B_i     EVI_i    EVI2_i           G_i   GNDVI_i  \
# system:index
# 2023-06-11     2032.645502  1.333429  0.485674   2332.866020  0.278185
# 2023-06-16     1800.477154  1.771959  0.673571   2169.249325  0.371426
# 2023-06-26     1739.425262  1.633281  0.718674   2139.771694  0.397118
# 2023-07-01    11210.579625 -0.030652  0.012627  10444.849174 -0.012232
# 2023-07-06     2103.518396  1.266013  0.562306   2440.528965  0.329122
#
#                 GVMI_i   MNDWI_i       MSAVI_i    NDBI_i    NDMI_i  ...  \
# system:index                                                        ...
# 2023-06-11    0.086086 -0.092435   3365.260648 -0.086076  0.086076  ...
# 2023-06-16    0.102976 -0.151795  -4003.870312 -0.102968  0.102968  ...
# 2023-06-26    0.096696 -0.193464  -5847.905594 -0.096688  0.096688  ...
# 2023-07-01    0.208115  0.303020  78854.914177 -0.208112  0.208112  ...
# 2023-07-06    0.107782 -0.123708    959.777495 -0.107774  0.107774  ...
#
# ...

# %%
######################## for NDVI

df = all_data_withprecip
df['date'] =  pd.to_datetime(df.index)

# create a figure and axis object
fig, ax1 = plt.subplots(figsize=(15, 6))

# plot the bar chart on the first axis
ax1.bar(df['date'], df['precipitation'], color='royalblue')

# set the y-axis label for the first axis
ax1.set_ylabel('precipitation [mm]', fontsize=12)


# create a second axis object that shares the same x-axis as the first axis
ax2 = ax1.twinx()

# plot the line chart on the second axis

x = date2num(df['date'])
ax2.bar(x, df['NDVI_i'], width=1, color='mediumseagreen')
ax2.bar(x+1, df['NDVI_ni'], width=1, color='goldenrod')

# set the y-axis label for the second axis
ax2.set_ylabel('NDVI', fontsize=12)

# set the x-axis label and title
ax1.set_xlabel('Date', fontsize=12)
ax1.set_title('Development of NDVI June - August 2023', fontsize=14)

ax1.set_ylim([0, 50])
ax2.set_ylim([0, 0.6])

ax1.invert_yaxis()
ax1.xaxis.set_major_locator(ticker.MultipleLocator(base=3))
fig.autofmt_xdate()
# show the plot
plt.show()

plt.savefig('NDVI.png')

# %%
######################## for EVI

df = all_data_withprecip
df['date'] =  pd.to_datetime(df.index)

# create a figure and axis object
fig, ax1 = plt.subplots(figsize=(15, 6))

# plot the bar chart on the first axis
ax1.bar(df['date'], df['precipitation'], color='royalblue')

# set the y-axis label for the first axis
ax1.set_ylabel('precipitation [mm]', fontsize=12)


# create a second axis object that shares the same x-axis as the first axis
ax2 = ax1.twinx()

# plot the line chart on the second axis

x = date2num(df['date'])
ax2.bar(x, df['EVI_i'], width=1, color='mediumseagreen')
ax2.bar(x+1, df['EVI_ni'], width=1, color='goldenrod')

# set the y-axis label for the second axis
ax2.set_ylabel('EVI', fontsize=12)

# set the x-axis label and title
ax1.set_xlabel('Date', fontsize=12)
ax1.set_title('Development of EVI June - August 2023', fontsize=14)

ax1.set_ylim([0, 50])
ax2.set_ylim([0, 2])

ax1.invert_yaxis()
ax1.xaxis.set_major_locator(ticker.MultipleLocator(base=3))
fig.autofmt_xdate()
# show the plot
plt.show()

plt.savefig('EVI.png')

# %%
######################## for NDMI

df = all_data_withprecip
df['date'] =  pd.to_datetime(df.index)

# create a figure and axis object
fig, ax1 = plt.subplots(figsize=(15, 6))

# plot the bar chart on the first axis
ax1.bar(df['date'], df['precipitation'], color='royalblue')

# set the y-axis label for the first axis
ax1.set_ylabel('precipitation [mm]', fontsize=12)


# create a second axis object that shares the same x-axis as the first axis
ax2 = ax1.twinx()

# plot the line chart on the second axis

x = date2num(df['date'])
ax2.bar(x, df['NDMI_i'], width=1, color='mediumseagreen')
ax2.bar(x+1, df['NDMI_ni'], width=1, color='goldenrod')

# set the y-axis label for the second axis
ax2.set_ylabel('NDMI', fontsize=12)

# set the x-axis label and title
ax1.set_xlabel('Date', fontsize=12)
ax1.set_title('Development of NDMI June - August 2023', fontsize=14)

ax1.set_ylim([0, 50])
ax2.set_ylim([0, 0.3])

ax1.invert_yaxis()
ax1.xaxis.set_major_locator(ticker.MultipleLocator(base=3))
fig.autofmt_xdate()
# show the plot
plt.show()

plt.savefig('NDMI.png')

# %%
######################## for GVMI

df = all_data_withprecip
df['date'] =  pd.to_datetime(df.index)

# create a figure and axis object
fig, ax1 = plt.subplots(figsize=(15, 6))

# plot the bar chart on the first axis
ax1.bar(df['date'], df['precipitation'], color='royalblue')

# set the y-axis label for the first axis
ax1.set_ylabel('precipitation [mm]', fontsize=12)


# create a second axis object that shares the same x-axis as the first axis
ax2 = ax1.twinx()

# plot the line chart on the second axis

x = date2num(df['date'])
ax2.bar(x, df['GVMI_i'], width=1, color='mediumseagreen')
ax2.bar(x+1, df['GVMI_ni'], width=1, color='goldenrod')

# set the y-axis label for the second axis
ax2.set_ylabel('GVMI', fontsize=12)

# set the x-axis label and title
ax1.set_xlabel('Date', fontsize=12)
ax1.set_title('Development of GVMI June - August 2023', fontsize=14)

ax1.set_ylim([0, 50])
ax2.set_ylim([0, 0.3])

ax1.invert_yaxis()
ax1.xaxis.set_major_locator(ticker.MultipleLocator(base=3))
fig.autofmt_xdate()
# show the plot
plt.show()

plt.savefig('GVMI.png')

# %%
######################## for NDWI

df = all_data_withprecip
df['date'] =  pd.to_datetime(df.index)

# create a figure and axis object
fig, ax1 = plt.subplots(figsize=(15, 6))

# plot the bar chart on the first axis
ax1.bar(df['date'], df['precipitation'], color='royalblue')

# set the y-axis label for the first axis
ax1.set_ylabel('precipitation [mm]', fontsize=12)


# create a second axis object that shares the same x-axis as the first axis
ax2 = ax1.twinx()

# plot the line chart on the second axis

x = date2num(df['date'])
ax2.bar(x, df['NDWI_i'], width=1, color='mediumseagreen')
ax2.bar(x+1, df['NDWI_ni'], width=1, color='goldenrod')

# set the y-axis label for the second axis
ax2.set_ylabel('NDWI', fontsize=12)

# set the x-axis label and title
ax1.set_xlabel('Date', fontsize=12)
ax1.set_title('Development of NDWI June - August 2023', fontsize=14)

ax1.set_ylim([0, 50])
ax2.set_ylim([0, 0.3])

ax1.invert_yaxis()
ax1.xaxis.set_major_locator(ticker.MultipleLocator(base=3))
fig.autofmt_xdate()
# show the plot
plt.show()

plt.savefig('NDWI.png')

# %%
######################## for SIWSI

df = all_data_withprecip
df['date'] =  pd.to_datetime(df.index)

# create a figure and axis object
fig, ax1 = plt.subplots(figsize=(15, 6))

# plot the bar chart on the first axis
ax1.bar(df['date'], df['precipitation'], color='royalblue')

# set the y-axis label for the first axis
ax1.set_ylabel('precipitation [mm]', fontsize=12)


# create a second axis object that shares the same x-axis as the first axis
ax2 = ax1.twinx()

# plot the line chart on the second axis

x = date2num(df['date'])
ax2.bar(x, df['SIWSI_i'], width=1, color='mediumseagreen')
ax2.bar(x+1, df['SIWSI_ni'], width=1, color='goldenrod')

# set the y-axis label for the second axis
ax2.set_ylabel('SIWSI', fontsize=12)

# set the x-axis label and title
ax1.set_xlabel('Date', fontsize=12)
ax1.set_title('Development of SIWSI June - August 2023', fontsize=14)

ax1.set_ylim([0, 50])
ax2.set_ylim([0, 0.2])

ax1.invert_yaxis()
ax1.xaxis.set_major_locator(ticker.MultipleLocator(base=3))
fig.autofmt_xdate()
# show the plot
plt.show()

plt.savefig('SIWSI.png')

# %%
######################## for EVI2

df = all_data_withprecip
df['date'] =  pd.to_datetime(df.index)

# create a figure and axis object
fig, ax1 = plt.subplots(figsize=(15, 6))

# plot the bar chart on the first axis
ax1.bar(df['date'], df['precipitation'], color='royalblue')

# set the y-axis label for the first axis
ax1.set_ylabel('precipitation [mm]', fontsize=12)


# create a second axis object that shares the same x-axis as the first axis
ax2 = ax1.twinx()

# plot the line chart on the second axis

x = date2num(df['date'])
ax2.bar(x, df['EVI2_i'], width=1, color='mediumseagreen')
ax2.bar(x+1, df['EVI2_ni'], width=1, color='goldenrod')

# set the y-axis label for the second axis
ax2.set_ylabel('EVI2', fontsize=12)

# set the x-axis label and title
ax1.set_xlabel('Date', fontsize=12)
ax1.set_title('Development of EVI2 June - August 2023', fontsize=14)

ax1.set_ylim([0, 50])
ax2.set_ylim([0, 1])

ax1.invert_yaxis()
ax1.xaxis.set_major_locator(ticker.MultipleLocator(base=3))
fig.autofmt_xdate()
# show the plot
plt.show()

plt.savefig('EVI2.png')

# %%
######################## for TERANIS Index

df = all_data_withprecip
df['date'] =  pd.to_datetime(df.index)

# create a figure and axis object
fig, ax1 = plt.subplots(figsize=(15, 6))

# plot the bar chart on the first axis
ax1.bar(df['date'], df['precipitation'], color='royalblue')

# set the y-axis label for the first axis
ax1.set_ylabel('precipitation [mm]', fontsize=12)


# create a second axis object that shares the same x-axis as the first axis
ax2 = ax1.twinx()

# plot the line chart on the second axis

x = date2num(df['date'])
ax2.bar(x, df['b1_i'], width=1, color='mediumseagreen')
ax2.bar(x+1, df['b1_ni'], width=1, color='goldenrod')

# set the y-axis label for the second axis
ax2.set_ylabel('b1', fontsize=12)

# set the x-axis label and title
ax1.set_xlabel('Date', fontsize=12)
ax1.set_title('Development of TERANIS index June - August 2023', fontsize=14)

ax1.set_ylim([0, 50])
ax2.set_ylim([0, -1.5])

ax1.invert_yaxis()
ax1.xaxis.set_major_locator(ticker.MultipleLocator(base=3))
fig.autofmt_xdate()
# show the plot
plt.show()

plt.savefig('TERANIS.png')

# %%
all_data.dtypes
# Out:
# B_i         float64
# EVI_i       float64
# EVI2_i      float64
# G_i         float64
# GNDVI_i     float64
# GVMI_i      float64
# MNDWI_i     float64
# MSAVI_i     float64
# NDBI_i      float64
# NDMI_i      float64
# NDRE_i      float64
# NDVI_i      float64
# NDWI_i      float64
# NDWI2_i     float64
# NIR_i       float64
# NRVI_i      float64
# R_i         float64
# RE1_i       float64
# RE2_i       float64
# RE3_i       float64
# RE4_i       float64
# RVI_i       float64
# SAVI_i      float64
# SIWSI_i     float64
# SLAVI_i     float64
# SR_i        float64
# b1_i        float64
# swir1_i     float64
# swir2_i     float64
# B_ni        float64
# EVI_ni      float64
# EVI2_ni     float64
# G_ni        float64
# GNDVI_ni    float64
# GVMI_ni     float64
# MNDWI_ni    float64
# MSAVI_ni    float64
# NDBI_ni     float64
# NDMI_ni     float64
# NDRE_ni     float64
# NDVI_ni     float64
# NDWI_ni     float64
# NDWI2_ni    float64
# NIR_ni      float64
# NRVI_ni     float64
# ...

# %%
##### Launch t-test to determine significance of observed differences 

stats.ttest_ind(all_data['NDVI_i'], all_data['NDVI_ni'])
# Out:
# Ttest_indResult(statistic=0.702047632258926, pvalue=0.488060949128556)

# %%
stats.ttest_ind(all_data['EVI_i'], all_data['EVI_ni'])
# Out:
# Ttest_indResult(statistic=0.6787548998080756, pvalue=0.5024961813251083)

# %%
stats.ttest_ind(all_data['EVI2_i'], all_data['EVI2_ni'])
# Out:
# Ttest_indResult(statistic=0.7962056057311053, pvalue=0.43216828248712846)

# %%
stats.ttest_ind(all_data['NDMI_i'], all_data['NDMI_ni'])
# Out:
# Ttest_indResult(statistic=1.5248655373028839, pvalue=0.1377666681025915)

# %%
stats.ttest_ind(all_data['GVMI_i'], all_data['GVMI_ni'])
# Out:
# Ttest_indResult(statistic=1.5249040482646163, pvalue=0.13775708775712167)

# %%
stats.ttest_ind(all_data['NDWI_i'], all_data['NDWI_ni'])
# Out:
# Ttest_indResult(statistic=-0.2872216964783995, pvalue=0.7759172107514573)

# %%
stats.ttest_ind(all_data['SIWSI_i'], all_data['SIWSI_ni'])
# Out:
# Ttest_indResult(statistic=1.9783401356191033, pvalue=0.05713701582461004)

# %%
stats.ttest_ind(all_data['SLAVI_i'], all_data['SLAVI_ni'])
# Out:
# Ttest_indResult(statistic=1.761660018599411, pvalue=0.08831618351020498)
